# %%
# !pip install datetime

# %%
#Import dependencies
import os
import pandas as pd
import datetime
import time
import numpy as np

# %%
#Open the raw data set
data_path = os.path.join("listings.csv")
listings_df = pd.read_csv(data_path)
listings_df
# Out:
#              id                            listing_url       scrape_id  \
# 0           109       https://www.airbnb.com/rooms/109  20200414051904
# 1           344       https://www.airbnb.com/rooms/344  20200414051904
# 2          2708      https://www.airbnb.com/rooms/2708  20200414051904
# 3          2732      https://www.airbnb.com/rooms/2732  20200414051904
# 4          2864      https://www.airbnb.com/rooms/2864  20200414051904
# ...         ...                                    ...             ...
# 37723  43177680  https://www.airbnb.com/rooms/43177680  20200414051904
# 37724  43177882  https://www.airbnb.com/rooms/43177882  20200414051904
# 37725  43178144  https://www.airbnb.com/rooms/43178144  20200414051904
# 37726  43178189  https://www.airbnb.com/rooms/43178189  20200414051904
# 37727  43178194  https://www.airbnb.com/rooms/43178194  20200414051904
#
#        last_scraped                                               name  \
# ...

# %%
#Make a copy of the raw data set to clean
listings_df_clean = listings_df.copy()
listings_df_clean
# Out:
#              id                            listing_url       scrape_id  \
# 0           109       https://www.airbnb.com/rooms/109  20200414051904
# 1           344       https://www.airbnb.com/rooms/344  20200414051904
# 2          2708      https://www.airbnb.com/rooms/2708  20200414051904
# 3          2732      https://www.airbnb.com/rooms/2732  20200414051904
# 4          2864      https://www.airbnb.com/rooms/2864  20200414051904
# ...         ...                                    ...             ...
# 37723  43177680  https://www.airbnb.com/rooms/43177680  20200414051904
# 37724  43177882  https://www.airbnb.com/rooms/43177882  20200414051904
# 37725  43178144  https://www.airbnb.com/rooms/43178144  20200414051904
# 37726  43178189  https://www.airbnb.com/rooms/43178189  20200414051904
# 37727  43178194  https://www.airbnb.com/rooms/43178194  20200414051904
#
#        last_scraped                                               name  \
# ...

# %%
#Drop irrelevant columns
listings_df_clean.drop(['scrape_id', 'last_scraped', 'summary', 'space', 'description',
                       'experiences_offered', 'neighborhood_overview', 'notes', 'transit', 
                        'access', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url',
                       'xl_picture_url', 'host_location', 'host_about', 'host_neighbourhood',
                       'host_total_listings_count', 'host_verifications', 'host_has_profile_pic',
                       'host_identity_verified', 'street', 'neighbourhood', 'smart_location',
                       'country_code', 'country', 'is_location_exact', 'bed_type', 'amenities',
                       'square_feet', 'guests_included','extra_people', 'maximum_nights', 
                        'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights',
                        'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm',
                        'calendar_updated', 'has_availability', 'calendar_last_scraped', 
                        'number_of_reviews_ltm', 'first_review', 'last_review', 'review_scores_accuracy',
                        'review_scores_checkin', 'review_scores_communication', 'review_scores_location',
                        'review_scores_value', 'requires_license', 'license', 'jurisdiction_names', 
                        'is_business_travel_ready', 'require_guest_profile_picture', 
                        'require_guest_phone_verification', 'calculated_host_listings_count',
                        'calculated_host_listings_count_entire_homes', 
                        'calculated_host_listings_count_private_rooms',
                        'calculated_host_listings_count_shared_rooms', 'availability_30', 'availability_60', 
                       'availability_365', 'market'], axis=1, inplace=True)
listings_df_clean
# Out:
#              id                            listing_url  \
# 0           109       https://www.airbnb.com/rooms/109
# 1           344       https://www.airbnb.com/rooms/344
# 2          2708      https://www.airbnb.com/rooms/2708
# 3          2732      https://www.airbnb.com/rooms/2732
# 4          2864      https://www.airbnb.com/rooms/2864
# ...         ...                                    ...
# 37723  43177680  https://www.airbnb.com/rooms/43177680
# 37724  43177882  https://www.airbnb.com/rooms/43177882
# 37725  43178144  https://www.airbnb.com/rooms/43178144
# 37726  43178189  https://www.airbnb.com/rooms/43178189
# 37727  43178194  https://www.airbnb.com/rooms/43178194
#
#                                                     name  \
# 0      Amazing bright elegant condo park front *UPGRA...
# 1                      Family perfect;Pool;Near Studios!
# 2      Mirrored Mini-Suite with Fireplace - W. Hollywood
# 3                                  Zen Life at the Beach
# ...

# %%
for col in listings_df_clean.columns: 
    print(col)
# Out:
# id
# listing_url
# name
# picture_url
# host_id
# host_url
# host_name
# host_since
# host_response_time
# host_response_rate
# host_acceptance_rate
# host_is_superhost
# host_thumbnail_url
# host_picture_url
# host_listings_count
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# city
# state
# zipcode
# latitude
# longitude
# property_type
# room_type
# accommodates
# bathrooms
# bedrooms
# beds
# price
# weekly_price
# monthly_price
# security_deposit
# cleaning_fee
# minimum_nights
# availability_90
# number_of_reviews
# review_scores_rating
# review_scores_cleanliness
# instant_bookable
# cancellation_policy
# reviews_per_month

# %%
listings_df_clean.to_csv (r'C:\listings_clean.csv', index = False, header=True)
